# %% [markdown]
# # Week 3 My work Reading CSV Files
#
# Author: Stephen Kerr

# %%
import pandas as pd

# %%
# Reading from my own file in my drive note adapted to remove the ID of the file
file_id = 'doc id in here'
url = f'https://drive.google.com/uc?export=download&id={file_id}'
df = pd.read_csv(url)
# Out:
# ---------------------------------------------------------------------------
# InvalidURL                                Traceback (most recent call last)
# Cell In[2], line 4
#       2 file_id = 'doc id in here'
#       3 url = f'https://drive.google.com/uc?export=download&id={file_id}'
# ----> 4 df = pd.read_csv(url)
#
# ...

# %%
type(df)

# %%
df.info()
